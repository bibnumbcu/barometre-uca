# %% [markdown]
# # <span style="color:orange">Obtention de statistiques sur les fichiers bruts</span>
# le but du traitement est d'obtenir :
# - combien il y a de publications sans doi
# - combien de doublons dans hal
# - combien de notices vides dans hal
#
# Il faut télécharger année par année, et toujours nommer les fichiers de la même manière.  <span style="color:red"> **Il est vital de garder l'organisation ici présente (Data > raw > dossier par année) pour que le code fonctionne.**</span>

# %%
column_name = "doi"

# %% [markdown]
# ## <span style="color:orange">Opérations préalables</span>
# ### import des fonctions utiles pour le traitement des données

# %%
# fonctions communes uca
from fonctions_uca import *

# %% [markdown]
# ## <span style="color:orange">Récupérer les données issues de hal</span>

# %% [markdown]
# ### récupérer le fichier de hal

# %%
hal_doi = read_all_csv("hal")

# %% [markdown]
# ### enlever les valeurs nulles

# %%
mask_hal_doi = hal_doi[column_name].notna()
mask_hal_doi
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3226    False
# 3227    False
# 3228    False
# 3229    False
# 3230    False
# Name: doi, Length: 3231, dtype: bool

# %%
doi_hal_only = hal_doi[mask_hal_doi]
#seulement les lignes avec des doi
doi_hal_only
# Out:
#       Annï¿½e      Identifiant Type dï¿½pï¿½t           Type document  Statut  \
# 0      2018.0     hal-01798998           file  Article dans une revue     NaN
# 1      2018.0     hal-01780702         notice  Article dans une revue     NaN
# 2      2018.0     hal-01701074         notice  Article dans une revue     NaN
# 3      2018.0     hal-01917284           file  Article dans une revue     NaN
# 4      2018.0     hal-01693402         notice  Article dans une revue     NaN
# ...       ...              ...            ...                     ...     ...
# 1747   2018.0     hal-01971027           file  Article dans une revue     NaN
# 1748   2018.0     hal-02307403         notice  Article dans une revue     NaN
# 1749   2018.0  halshs-01495427           file  Article dans une revue     NaN
# 1750   2018.0     hal-01793391         notice  Article dans une revue     NaN
# 1751   2018.0     hal-01788494         notice  Article dans une revue     NaN
#
#                                                 Auteurs  \
# 0           Emmanuel Futier, Bruno Pereira, Samir Jaber
# 1     Frï¿½dï¿½ric Garban, Audrey Guyard, Helene Lab...
# 2     Hannah Jongsma, Charlotte Gayer-Anderson, Anto...
# 3     Stï¿½phanie Maupetit-Mï¿½houas, Franck Court, ...
# 4     Martin Guitreau, Nicolas Mora, Jean-Louis Paqu...
# ...                                                 ...
# 1747  Jean Bï¿½langer, Basma Frangieh, Eugï¿½ne Graz...
# 1748  Xavier Hollandts, Nicolas Aubert, Abdelmehdi B...
# 1749  Xavier Hollandts, Nicolas Aubert, Abdelmehdi A...
# 1750  Teresa Oberc-Dziedzic, Ryszard Kryza, Stanis?a...
# 1751  Yassine Bouattour, Philip Chennell, Mathieu Wa...
#
#                                                   Titre  \
# 0     Organ Dysfunction After Surgery in Patients Tr...
# 1     Comparison of the Hemostatic Efficacy of Patho...
# 2     Treated Incidence of Psychotic Disorders in th...
# 3     DNA methylation profiling reveals a pathologic...
# 4     Crystallization and Disturbance Histories of S...
# ...                                                 ...
# 1747  Inclusive school: behind the words, what are t...
# 1748  Beyond Dichotomy: The Curvilinear Impact of Em...
# 1749  Beyond Dichotomy: The Curvilinear Impact of Em...
# 1750  The Saxothuringian Terrane affinity of the met...
# 1751  Stability of an ophthalmic formulation of poly...
#
#                                            Affiliations  \
# 0     GReD , service de Biostatistiques, DRCI, PhyMe...
# 1                                          CHELTER, UCA
# 2     Service de psychiatrie, Dept. of Psychiatry, A...
# 3                                          CHELTER, UCA
# 4     LMV, EMC LAB, INSU - CNRS, UJM, Institut de Re...
# ...                                                 ...
# 1747                    LABPE, ACTï¿½, UQAM, LABPE, UBP
# 1748  CRCGM et IFGE, CERGAM, CleRMa, DRM, Kedge BS, ...
# 1749  CRCGM et IFGE, CERGAM, AMU IAE, CleRMa, DRM, K...
# 1750  Institute of Geological Sciences, Institute of...
# 1751  CHU Clermont-Ferrand, Service Pharmacie, ICCF,...
#
#                                                 Projets Rï¿½fï¿½rence interne  \
# 0                                                   NaN                   NaN
# 1                                                   NaN                   NaN
# 2                                                   NaN                   NaN
# 3                                                   NaN             Emergence
# 4     anrProject projanr-37828 (Clermont-Ferrand cen...           Challenge 4
# ...                                                 ...                   ...
# 1747                                                NaN                   NaN
# 1748                                                NaN                   NaN
# 1749                                                NaN                   NaN
# 1750                                                NaN                   NaN
# 1751                                                NaN                   NaN
#
#                                    doi Actes   linkExtId
# 0              10.1001/jama.2017.20956   NaN  openaccess
# 1          10.1001/jamaoncol.2017.5123   NaN  openaccess
# 2     10.1001/jamapsychiatry.2017.3554   NaN  openaccess
# 3              10.1002/1878-0261.12191   NaN  openaccess
# 4                 10.1002/2017GC007310   NaN         NaN
# ...                                ...   ...         ...
# 1747                 10.7202/1054160ar   NaN  openaccess
# 1748                 10.7202/1058165ar   NaN  openaccess
# 1749                 10.7202/1058165ar   NaN  openaccess
# 1750                   10.7306/gq.1405   NaN  openaccess
# 1751                10.7717/peerj.4549   NaN  openaccess
#
# [1752 rows x 13 columns]

# %% [markdown]
# ### compter le nombre de publis de hal sans doi

# %%
doi_hal_nan_count = len(hal_doi) - len(doi_hal_only)
doi_hal_nan_count
# Out:
# 1479

# %% [markdown]
# ### compter le nombre de doublons de hal

# %%
#on passe en minuscule tous les doi
doi_hal_minuscule = doi_hal_only[column_name].str.lower()

# %%
#passage par une dataFrame
doi_hal_doublons_df = pandas.DataFrame({column_name : doi_hal_minuscule})

# %%
hal_duplicates = len(doi_hal_only)- len(doi_hal_doublons_df.drop_duplicates())
hal_duplicates
# Out:
# 25

# %%
#nombre de doublons
hal_duplicates.count()
# Out:
# doi    25
# dtype: int64

# %% [markdown]
# ## <span style="color:orange">Récupérer les données du WOS</span>

# %%
wos_doi = read_all_csv("wos")
wos_doi
# Out:
#          adrCleost                                            adresse  \
# 0      216857731P1  Univ Clermont Auvergne, INRA, MEDiS UMR454, F-...
# 1      216857731P2  INRA, Ctr Auvergne Rhoone Alpes, Microbiol Env...
# 2      216860861P1  Univ Lyon 1, Univ Lyon, Team Vasc Biol & Red B...
# 3      216861514P8  Ctr Hosp Univ Clermont Ferrand, Dept Neuroradi...
# 4      216863626P3  Univ Clermont Auvergne, Inst Pascal, 24 Ave La...
# ...            ...                                                ...
# 3411  223961187P24  Univ Clermont Auvergne, CNRS UMR6016, Observ P...
# 3412  223962219P12  CHU Clermont Ferrand, Serv Endocrinol Diabetol...
# 3413  223962219P13  Univ Clermont Auvergne, UFR Med, 28 Pl Henri D...
# 3414  223962219P14  Univ Clermont Auvergne, Genet Reprod & Dev, IN...
# 3415  223962219P15  CHU G Montpied, Endocrinol Diabetol, BP 69, F-...
#
#      codePostal                    ville Statut  anneePubli Domaine  \
# 0         63000         CLERMONT-FERRAND     NC        2018     SMV
# 1         63122  SAINT-GENES-CHAMPANELLE     NC        2018     SMV
# 2           NaN                     LYON     NC        2018     SMV
# 3           NaN         CLERMONT-FERRAND     NC        2018     SMV
# 4         63177                  AUBIERE     NC        2018     SMV
# ...         ...                      ...    ...         ...     ...
# 3411        NaN                  AUBIERE      C        2018     SMV
# 3412      63000         CLERMONT-FERRAND      C        2018     SMV
# 3413      63000         CLERMONT-FERRAND      C        2018     SMV
# 3414      63170                  AUBIERE      C        2018     SMV
# 3415      63003         CLERMONT-FERRAND      C        2018     SMV
#
#                                           Titre Article Titre Journal  \
# 0     Desiccation: An environmental and food industr...   FOOD MICROB
# 1     Desiccation: An environmental and food industr...   FOOD MICROB
# 2     Does physical activity increase or decrease th...   BR J SP MED
# 3     Second-Generation Hydrogel Coils for the Endov...        STROKE
# 4     High frequency transformer model derived from ...    INT J ELEC
# ...                                                 ...           ...
# 3411  Global analysis of continental boundary layer ...   ATMOS CH PH
# 3412  Perioperative management of adult diabetic pat...   ANA CRIT CA
# 3413  Perioperative management of adult diabetic pat...   ANA CRIT CA
# 3414  Perioperative management of adult diabetic pat...   ANA CRIT CA
# 3415  Perioperative management of adult diabetic pat...   ANA CRIT CA
#
#                                doi
# 0         10.1016/j.fm.2017.07.017
# 1         10.1016/j.fm.2017.07.017
# 2     10.1136/bjsports-2015-095317
# 3     10.1161/STROKEAHA.117.018707
# 4     10.1016/j.ijepes.2017.07.017
# ...                            ...
# 3411     10.5194/acp-18-14737-2018
# 3412   10.1016/j.accpm.2018.02.020
# 3413   10.1016/j.accpm.2018.02.020
# 3414   10.1016/j.accpm.2018.02.020
# 3415   10.1016/j.accpm.2018.02.020
#
# [3416 rows x 10 columns]

# %% [markdown]
# ### enlever les valeurs nulles

# %%
mask_wos_doi = wos_doi[column_name].notna()
mask_wos_doi
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 3411    True
# 3412    True
# 3413    True
# 3414    True
# 3415    True
# Name: doi, Length: 3416, dtype: bool

# %%
doi_wos_only = wos_doi[mask_wos_doi]
doi_wos_only
# Out:
#          adrCleost                                            adresse  \
# 0      216857731P1  Univ Clermont Auvergne, INRA, MEDiS UMR454, F-...
# 1      216857731P2  INRA, Ctr Auvergne Rhoone Alpes, Microbiol Env...
# 2      216860861P1  Univ Lyon 1, Univ Lyon, Team Vasc Biol & Red B...
# 3      216861514P8  Ctr Hosp Univ Clermont Ferrand, Dept Neuroradi...
# 4      216863626P3  Univ Clermont Auvergne, Inst Pascal, 24 Ave La...
# ...            ...                                                ...
# 3411  223961187P24  Univ Clermont Auvergne, CNRS UMR6016, Observ P...
# 3412  223962219P12  CHU Clermont Ferrand, Serv Endocrinol Diabetol...
# 3413  223962219P13  Univ Clermont Auvergne, UFR Med, 28 Pl Henri D...
# 3414  223962219P14  Univ Clermont Auvergne, Genet Reprod & Dev, IN...
# 3415  223962219P15  CHU G Montpied, Endocrinol Diabetol, BP 69, F-...
#
#      codePostal                    ville Statut  anneePubli Domaine  \
# 0         63000         CLERMONT-FERRAND     NC        2018     SMV
# 1         63122  SAINT-GENES-CHAMPANELLE     NC        2018     SMV
# 2           NaN                     LYON     NC        2018     SMV
# 3           NaN         CLERMONT-FERRAND     NC        2018     SMV
# 4         63177                  AUBIERE     NC        2018     SMV
# ...         ...                      ...    ...         ...     ...
# 3411        NaN                  AUBIERE      C        2018     SMV
# 3412      63000         CLERMONT-FERRAND      C        2018     SMV
# 3413      63000         CLERMONT-FERRAND      C        2018     SMV
# 3414      63170                  AUBIERE      C        2018     SMV
# 3415      63003         CLERMONT-FERRAND      C        2018     SMV
#
#                                           Titre Article Titre Journal  \
# 0     Desiccation: An environmental and food industr...   FOOD MICROB
# 1     Desiccation: An environmental and food industr...   FOOD MICROB
# 2     Does physical activity increase or decrease th...   BR J SP MED
# 3     Second-Generation Hydrogel Coils for the Endov...        STROKE
# 4     High frequency transformer model derived from ...    INT J ELEC
# ...                                                 ...           ...
# 3411  Global analysis of continental boundary layer ...   ATMOS CH PH
# 3412  Perioperative management of adult diabetic pat...   ANA CRIT CA
# 3413  Perioperative management of adult diabetic pat...   ANA CRIT CA
# 3414  Perioperative management of adult diabetic pat...   ANA CRIT CA
# 3415  Perioperative management of adult diabetic pat...   ANA CRIT CA
#
#                                doi
# 0         10.1016/j.fm.2017.07.017
# 1         10.1016/j.fm.2017.07.017
# 2     10.1136/bjsports-2015-095317
# 3     10.1161/STROKEAHA.117.018707
# 4     10.1016/j.ijepes.2017.07.017
# ...                            ...
# 3411     10.5194/acp-18-14737-2018
# 3412   10.1016/j.accpm.2018.02.020
# 3413   10.1016/j.accpm.2018.02.020
# 3414   10.1016/j.accpm.2018.02.020
# 3415   10.1016/j.accpm.2018.02.020
#
# [2280 rows x 10 columns]

# %% [markdown]
# ### compter le nombre de publis de wos sans doi

# %%
doi_wos_nan_count = len(wos_doi) - len(doi_wos_only)
doi_wos_nan_count
# Out:
# 1136

# %% [markdown]
# ### compter le nombre de doublons de wos

# %%
#on passe en minuscule tous les doi
doi_wos_minuscule = doi_wos_only[column_name].str.lower()

# %%
#passage par une dataFrame
doi_wos_doublons_df = pandas.DataFrame({column_name : doi_wos_minuscule})

# %%
wos_duplicates = len(doi_wos_only)- len(doi_wos_doublons_df.drop_duplicates())
wos_duplicates
# Out:
# 767
